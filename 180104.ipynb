# %%
! pip install --user flask
# Out:
# Requirement already satisfied: flask in /home/b10323061/.local/lib/python3.5/site-packages
# Requirement already satisfied: click>=2.0 in /home/b10323061/.local/lib/python3.5/site-packages (from flask)
# Requirement already satisfied: itsdangerous>=0.21 in /home/b10323061/.local/lib/python3.5/site-packages (from flask)
# Requirement already satisfied: Jinja2>=2.4 in /usr/local/lib/python3.5/dist-packages (from flask)
# Requirement already satisfied: Werkzeug>=0.7 in /home/b10323061/.local/lib/python3.5/site-packages (from flask)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.5/dist-packages (from Jinja2>=2.4->flask)

# %%
from flask import Flask, request, make_response, jsonify

app = Flask('flask-api')

@app.route('/')
def hello_world():
    message = {'message': 'hello world'}
    return jsonify(message)


from ptt_crawler import PttCrawler

@app.route('/ptt_crawler', methods=['GET','POST'])
def run_crawler():
    if request.method == 'GET':
        crawler = PttCrawler('Gossiping', page=1)
    elif request.method == 'POST':
        board = request.get_json().get('board','Gossiping')
        page = request.get_json().get('page','1')
        crawler = PttCrawler(board, page=page)
    result = crawler.run()
    return jsonify(result)

if __name__ == '__main__':
    app.run(port=8000)

# %%
print(app)
print('-------------------')
print(vars(app))
print('-------------------')
print(', '.join("%s: %s" % item for item in vars(app).items()))
print('-------------------')
print(app.__dict__)
print('-------------------')
print(dir(app))
# Out:
# <Flask 'flask-api'>
# -------------------
# {'template_folder': 'templates', '_logger': None, 'root_path': '/home/b10323061/ML', 'instance_path': '/home/b10323061/ML/instance', 'teardown_appcontext_funcs': [], 'url_value_preprocessors': {}, 'import_name': 'flask-api', 'before_first_request_funcs': [], 'teardown_request_funcs': {}, 'blueprints': {}, '_error_handlers': {}, 'url_default_functions': {}, 'url_map': Map([<Rule '/ptt_crawler' (HEAD, POST, OPTIONS, GET) -> run_crawler>,
#  <Rule '/' (HEAD, OPTIONS, GET) -> hello_world>,
#  <Rule '/static/<filename>' (HEAD, OPTIONS, GET) -> static>]), 'name': 'flask-api', 'shell_context_processors': [], '_static_folder': 'static', '_got_first_request': True, 'after_request_funcs': {}, 'view_functions': {'static': <bound method _PackageBoundObject.send_static_file of <Flask 'flask-api'>>, 'hello_world': <function hello_world at 0x7f293310b1e0>, 'run_crawler': <function run_crawler at 0x7f293310b730>}, '_blueprint_order': [], 'config': <Config {'SERVER_NAME': None, 'USE_X_SENDFILE': False, 'PROPAGATE_EXCEPTIONS': None, 'SESSION_COOKIE_SECURE': False, 'MAX_CONTENT_LENGTH': None, 'TRAP_BAD_REQUEST_ERRORS': False, 'SECRET_KEY': None, 'JSONIFY_MIMETYPE': 'application/json', 'SESSION_COOKIE_HTTPONLY': True, 'PREFERRED_URL_SCHEME': 'http', 'SEND_FILE_MAX_AGE_DEFAULT': datetime.timedelta(0, 43200), 'JSON_SORT_KEYS': True, 'TEMPLATES_AUTO_RELOAD': None, 'PRESERVE_CONTEXT_ON_EXCEPTION': None, 'DEBUG': False, 'JSON_AS_ASCII': True, 'APPLICATION_ROOT': None, 'PERMANENT_SESSION_LIFETIME': datetime.timedelta(31), 'TESTING': False, 'EXPLAIN_TEMPLATE_LOADING': False, 'TRAP_HTTP_EXCEPTIONS': False, 'LOGGER_NAME': 'flask-api', 'JSONIFY_PRETTYPRINT_REGULAR': True, 'LOGGER_HANDLER_POLICY': 'always', 'SESSION_COOKIE_PATH': None, 'SESSION_COOKIE_DOMAIN': None, 'SESSION_REFRESH_EACH_REQUEST': True, 'SESSION_COOKIE_NAME': 'session'}>, 'template_context_processors': {None: [<function _default_template_ctx_processor at 0x7f29411e0e18>]}, 'error_handler_spec': {None: {}}, 'url_build_error_handlers': [], 'before_request_funcs': {}, 'cli': <flask.cli.AppGroup object at 0x7f29330df550>, 'extensions': {}, '_before_request_lock': <unlocked _thread.lock object at 0x7f29338f0c88>, '_static_url_path': None}
# -------------------
# template_folder: templates, _logger: None, root_path: /home/b10323061/ML, instance_path: /home/b10323061/ML/instance, teardown_appcontext_funcs: [], url_value_preprocessors: {}, import_name: flask-api, before_first_request_funcs: [], teardown_request_funcs: {}, blueprints: {}, _error_handlers: {}, url_default_functions: {}, url_map: Map([<Rule '/ptt_crawler' (HEAD, POST, OPTIONS, GET) -> run_crawler>,
#  <Rule '/' (HEAD, OPTIONS, GET) -> hello_world>,
#  <Rule '/static/<filename>' (HEAD, OPTIONS, GET) -> static>]), name: flask-api, shell_context_processors: [], _static_folder: static, _got_first_request: True, after_request_funcs: {}, view_functions: {'static': <bound method _PackageBoundObject.send_static_file of <Flask 'flask-api'>>, 'hello_world': <function hello_world at 0x7f293310b1e0>, 'run_crawler': <function run_crawler at 0x7f293310b730>}, _blueprint_order: [], config: <Config {'SERVER_NAME': None, 'USE_X_SENDFILE': False, 'PROPAGATE_EXCEPTIONS': None, 'SESSION_COOKIE_SECURE': False, 'MAX_CONTENT_LENGTH': None, 'TRAP_BAD_REQUEST_ERRORS': False, 'SECRET_KEY': None, 'JSONIFY_MIMETYPE': 'application/json', 'SESSION_COOKIE_HTTPONLY': True, 'PREFERRED_URL_SCHEME': 'http', 'SEND_FILE_MAX_AGE_DEFAULT': datetime.timedelta(0, 43200), 'JSON_SORT_KEYS': True, 'TEMPLATES_AUTO_RELOAD': None, 'PRESERVE_CONTEXT_ON_EXCEPTION': None, 'DEBUG': False, 'JSON_AS_ASCII': True, 'APPLICATION_ROOT': None, 'PERMANENT_SESSION_LIFETIME': datetime.timedelta(31), 'TESTING': False, 'EXPLAIN_TEMPLATE_LOADING': False, 'TRAP_HTTP_EXCEPTIONS': False, 'LOGGER_NAME': 'flask-api', 'JSONIFY_PRETTYPRINT_REGULAR': True, 'LOGGER_HANDLER_POLICY': 'always', 'SESSION_COOKIE_PATH': None, 'SESSION_COOKIE_DOMAIN': None, 'SESSION_REFRESH_EACH_REQUEST': True, 'SESSION_COOKIE_NAME': 'session'}>, template_context_processors: {None: [<function _default_template_ctx_processor at 0x7f29411e0e18>]}, error_handler_spec: {None: {}}, url_build_error_handlers: [], before_request_funcs: {}, cli: <flask.cli.AppGroup object at 0x7f29330df550>, extensions: {}, _before_request_lock: <unlocked _thread.lock object at 0x7f29338f0c88>, _static_url_path: None
# -------------------
# {'template_folder': 'templates', '_logger': None, 'root_path': '/home/b10323061/ML', 'instance_path': '/home/b10323061/ML/instance', 'teardown_appcontext_funcs': [], 'url_value_preprocessors': {}, 'import_name': 'flask-api', 'before_first_request_funcs': [], 'teardown_request_funcs': {}, 'blueprints': {}, '_error_handlers': {}, 'url_default_functions': {}, 'url_map': Map([<Rule '/ptt_crawler' (HEAD, POST, OPTIONS, GET) -> run_crawler>,
#  <Rule '/' (HEAD, OPTIONS, GET) -> hello_world>,
#  <Rule '/static/<filename>' (HEAD, OPTIONS, GET) -> static>]), 'name': 'flask-api', 'shell_context_processors': [], '_static_folder': 'static', '_got_first_request': True, 'after_request_funcs': {}, 'view_functions': {'static': <bound method _PackageBoundObject.send_static_file of <Flask 'flask-api'>>, 'hello_world': <function hello_world at 0x7f293310b1e0>, 'run_crawler': <function run_crawler at 0x7f293310b730>}, '_blueprint_order': [], 'config': <Config {'SERVER_NAME': None, 'USE_X_SENDFILE': False, 'PROPAGATE_EXCEPTIONS': None, 'SESSION_COOKIE_SECURE': False, 'MAX_CONTENT_LENGTH': None, 'TRAP_BAD_REQUEST_ERRORS': False, 'SECRET_KEY': None, 'JSONIFY_MIMETYPE': 'application/json', 'SESSION_COOKIE_HTTPONLY': True, 'PREFERRED_URL_SCHEME': 'http', 'SEND_FILE_MAX_AGE_DEFAULT': datetime.timedelta(0, 43200), 'JSON_SORT_KEYS': True, 'TEMPLATES_AUTO_RELOAD': None, 'PRESERVE_CONTEXT_ON_EXCEPTION': None, 'DEBUG': False, 'JSON_AS_ASCII': True, 'APPLICATION_ROOT': None, 'PERMANENT_SESSION_LIFETIME': datetime.timedelta(31), 'TESTING': False, 'EXPLAIN_TEMPLATE_LOADING': False, 'TRAP_HTTP_EXCEPTIONS': False, 'LOGGER_NAME': 'flask-api', 'JSONIFY_PRETTYPRINT_REGULAR': True, 'LOGGER_HANDLER_POLICY': 'always', 'SESSION_COOKIE_PATH': None, 'SESSION_COOKIE_DOMAIN': None, 'SESSION_REFRESH_EACH_REQUEST': True, 'SESSION_COOKIE_NAME': 'session'}>, 'template_context_processors': {None: [<function _default_template_ctx_processor at 0x7f29411e0e18>]}, 'error_handler_spec': {None: {}}, 'url_build_error_handlers': [], 'before_request_funcs': {}, 'cli': <flask.cli.AppGroup object at 0x7f29330df550>, 'extensions': {}, '_before_request_lock': <unlocked _thread.lock object at 0x7f29338f0c88>, '_static_url_path': None}
# -------------------
# ['__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_before_request_lock', '_blueprint_order', '_error_handlers', '_find_error_handler', '_get_exc_class_and_code', '_got_first_request', '_logger', '_register_error_handler', '_static_folder', '_static_url_path', 'add_template_filter', 'add_template_global', 'add_template_test', 'add_url_rule', 'after_request', 'after_request_funcs', 'app_context', 'app_ctx_globals_class', 'auto_find_instance_path', 'before_first_request', 'before_first_request_funcs', 'before_request', 'before_request_funcs', 'blueprints', 'cli', 'config', 'config_class', 'context_processor', 'create_global_jinja_loader', 'create_jinja_environment', 'create_url_adapter', 'debug', 'default_config', 'dispatch_request', 'do_teardown_appcontext', 'do_teardown_request', 'endpoint', 'error_handler_spec', 'error_handlers', 'errorhandler', 'extensions', 'finalize_request', 'full_dispatch_request', 'get_send_file_max_age', 'got_first_request', 'handle_exception', 'handle_http_exception', 'handle_url_build_error', 'handle_user_exception', 'has_static_folder', 'import_name', 'init_jinja_globals', 'inject_url_defaults', 'instance_path', 'iter_blueprints', 'jinja_env', 'jinja_environment', 'jinja_loader', 'jinja_options', 'json_decoder', 'json_encoder', 'log_exception', 'logger', 'logger_name', 'make_config', 'make_default_options_response', 'make_null_session', 'make_response', 'make_shell_context', 'name', 'open_instance_resource', 'open_resource', 'open_session', 'permanent_session_lifetime', 'preprocess_request', 'preserve_context_on_exception', 'process_response', 'propagate_exceptions', 'raise_routing_exception', 'register_blueprint', 'register_error_handler', 'request_class', 'request_context', 'request_globals_class', 'response_class', 'root_path', 'route', 'run', 'save_session', 'secret_key', 'select_jinja_autoescape', 'send_file_max_age_default', 'send_static_file', 'session_cookie_name', 'session_interface', 'shell_context_processor', 'shell_context_processors', 'should_ignore_error', 'static_folder', 'static_url_path', 'teardown_appcontext', 'teardown_appcontext_funcs', 'teardown_request', 'teardown_request_funcs', 'template_context_processors', 'template_filter', 'template_folder', 'template_global', 'template_test', 'test_client', 'test_client_class', 'test_request_context', 'testing', 'trap_http_exception', 'try_trigger_before_first_request_functions', 'update_template_context', 'url_build_error_handlers', 'url_default_functions', 'url_defaults', 'url_map', 'url_rule_class', 'url_value_preprocessor', 'url_value_preprocessors', 'use_x_sendfile', 'view_functions', 'wsgi_app']

# %%
print(app.test_client())
print('-------------------')
print(vars(app.test_client()))
print('-------------------')
print(', '.join("%s: %s" % item for item in vars(app.test_client()).items()))
print('-------------------')
print(app.test_client().__dict__)
print('-------------------')
print(dir(app))
# Out:
# <FlaskClient <Flask 'flask-api'>>
# -------------------
# {'response_wrapper': <class 'flask.wrappers.Response'>, 'environ_base': {'REMOTE_ADDR': '127.0.0.1', 'HTTP_USER_AGENT': 'werkzeug/0.14.1'}, 'application': <Flask 'flask-api'>, 'allow_subdomain_redirects': False, 'cookie_jar': <_TestCookieJar[]>}
# -------------------
# response_wrapper: <class 'flask.wrappers.Response'>, environ_base: {'REMOTE_ADDR': '127.0.0.1', 'HTTP_USER_AGENT': 'werkzeug/0.14.1'}, application: <Flask 'flask-api'>, allow_subdomain_redirects: False, cookie_jar: <_TestCookieJar[]>
# -------------------
# {'response_wrapper': <class 'flask.wrappers.Response'>, 'environ_base': {'REMOTE_ADDR': '127.0.0.1', 'HTTP_USER_AGENT': 'werkzeug/0.14.1'}, 'application': <Flask 'flask-api'>, 'allow_subdomain_redirects': False, 'cookie_jar': <_TestCookieJar[]>}
# -------------------
# ['__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_before_request_lock', '_blueprint_order', '_error_handlers', '_find_error_handler', '_get_exc_class_and_code', '_got_first_request', '_logger', '_register_error_handler', '_static_folder', '_static_url_path', 'add_template_filter', 'add_template_global', 'add_template_test', 'add_url_rule', 'after_request', 'after_request_funcs', 'app_context', 'app_ctx_globals_class', 'auto_find_instance_path', 'before_first_request', 'before_first_request_funcs', 'before_request', 'before_request_funcs', 'blueprints', 'cli', 'config', 'config_class', 'context_processor', 'create_global_jinja_loader', 'create_jinja_environment', 'create_url_adapter', 'debug', 'default_config', 'dispatch_request', 'do_teardown_appcontext', 'do_teardown_request', 'endpoint', 'error_handler_spec', 'error_handlers', 'errorhandler', 'extensions', 'finalize_request', 'full_dispatch_request', 'get_send_file_max_age', 'got_first_request', 'handle_exception', 'handle_http_exception', 'handle_url_build_error', 'handle_user_exception', 'has_static_folder', 'import_name', 'init_jinja_globals', 'inject_url_defaults', 'instance_path', 'iter_blueprints', 'jinja_env', 'jinja_environment', 'jinja_loader', 'jinja_options', 'json_decoder', 'json_encoder', 'log_exception', 'logger', 'logger_name', 'make_config', 'make_default_options_response', 'make_null_session', 'make_response', 'make_shell_context', 'name', 'open_instance_resource', 'open_resource', 'open_session', 'permanent_session_lifetime', 'preprocess_request', 'preserve_context_on_exception', 'process_response', 'propagate_exceptions', 'raise_routing_exception', 'register_blueprint', 'register_error_handler', 'request_class', 'request_context', 'request_globals_class', 'response_class', 'root_path', 'route', 'run', 'save_session', 'secret_key', 'select_jinja_autoescape', 'send_file_max_age_default', 'send_static_file', 'session_cookie_name', 'session_interface', 'shell_context_processor', 'shell_context_processors', 'should_ignore_error', 'static_folder', 'static_url_path', 'teardown_appcontext', 'teardown_appcontext_funcs', 'teardown_request', 'teardown_request_funcs', 'template_context_processors', 'template_filter', 'template_folder', 'template_global', 'template_test', 'test_client', 'test_client_class', 'test_request_context', 'testing', 'trap_http_exception', 'try_trigger_before_first_request_functions', 'update_template_context', 'url_build_error_handlers', 'url_default_functions', 'url_defaults', 'url_map', 'url_rule_class', 'url_value_preprocessor', 'url_value_preprocessors', 'use_x_sendfile', 'view_functions', 'wsgi_app']

# %%
print(app.test_client().get('/'))
print('-------------------')
print(vars(app.test_client().get('/')))
print('-------------------')
print(', '.join("%s: %s" % item for item in vars(app.test_client().get('/')).items()))
print('-------------------')
print(app.test_client().get('/').__dict__)
print('-------------------')
print(dir(app))
# Out:
# <Response streamed [200 OK]>
# -------------------
# {'_on_close': [], '_status': '200 OK', 'response': <werkzeug.wsgi.ClosingIterator object at 0x7f293101a7f0>, 'headers': Headers([('Content-Type', 'application/json'), ('Content-Length', '31')]), '_status_code': 200, 'direct_passthrough': False}
# -------------------
# _on_close: [], _status: 200 OK, response: <werkzeug.wsgi.ClosingIterator object at 0x7f293101a8d0>, headers: Content-Type: application/json
# Content-Length: 31
#
# , _status_code: 200, direct_passthrough: False
# -------------------
# {'_on_close': [], '_status': '200 OK', 'response': <werkzeug.wsgi.ClosingIterator object at 0x7f29310eaeb8>, 'headers': Headers([('Content-Type', 'application/json'), ('Content-Length', '31')]), '_status_code': 200, 'direct_passthrough': False}
# -------------------
# ['__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_before_request_lock', '_blueprint_order', '_error_handlers', '_find_error_handler', '_get_exc_class_and_code', '_got_first_request', '_logger', '_register_error_handler', '_static_folder', '_static_url_path', 'add_template_filter', 'add_template_global', 'add_template_test', 'add_url_rule', 'after_request', 'after_request_funcs', 'app_context', 'app_ctx_globals_class', 'auto_find_instance_path', 'before_first_request', 'before_first_request_funcs', 'before_request', 'before_request_funcs', 'blueprints', 'cli', 'config', 'config_class', 'context_processor', 'create_global_jinja_loader', 'create_jinja_environment', 'create_url_adapter', 'debug', 'default_config', 'dispatch_request', 'do_teardown_appcontext', 'do_teardown_request', 'endpoint', 'error_handler_spec', 'error_handlers', 'errorhandler', 'extensions', 'finalize_request', 'full_dispatch_request', 'get_send_file_max_age', 'got_first_request', 'handle_exception', 'handle_http_exception', 'handle_url_build_error', 'handle_user_exception', 'has_static_folder', 'import_name', 'init_jinja_globals', 'inject_url_defaults', 'instance_path', 'iter_blueprints', 'jinja_env', 'jinja_environment', 'jinja_loader', 'jinja_options', 'json_decoder', 'json_encoder', 'log_exception', 'logger', 'logger_name', 'make_config', 'make_default_options_response', 'make_null_session', 'make_response', 'make_shell_context', 'name', 'open_instance_resource', 'open_resource', 'open_session', 'permanent_session_lifetime', 'preprocess_request', 'preserve_context_on_exception', 'process_response', 'propagate_exceptions', 'raise_routing_exception', 'register_blueprint', 'register_error_handler', 'request_class', 'request_context', 'request_globals_class', 'response_class', 'root_path', 'route', 'run', 'save_session', 'secret_key', 'select_jinja_autoescape', 'send_file_max_age_default', 'send_static_file', 'session_cookie_name', 'session_interface', 'shell_context_processor', 'shell_context_processors', 'should_ignore_error', 'static_folder', 'static_url_path', 'teardown_appcontext', 'teardown_appcontext_funcs', 'teardown_request', 'teardown_request_funcs', 'template_context_processors', 'template_filter', 'template_folder', 'template_global', 'template_test', 'test_client', 'test_client_class', 'test_request_context', 'testing', 'trap_http_exception', 'try_trigger_before_first_request_functions', 'update_template_context', 'url_build_error_handlers', 'url_default_functions', 'url_defaults', 'url_map', 'url_rule_class', 'url_value_preprocessor', 'url_value_preprocessors', 'use_x_sendfile', 'view_functions', 'wsgi_app']

# %%
import json

resp = app.test_client().get('/')
print(resp.data)
print(resp.data.decode())
print(json.loads(resp.data.decode()))
# Out:
# b'{\n  "message": "hello world"\n}\n'
# {
#   "message": "hello world"
# }
#
# {'message': 'hello world'}

# %%
from ptt_crawler import PttCrawler

crawler = PttCrawler('Gossiping', page=1)
result = crawler.run()
print(result)
# Out:
# [{'date': 'Thu Jan  4 14:11:47 2018', 'author': 'sumade (斬卍凱蒂貓卍佛)', 'title': 'Re: [新聞] 陳喬恩酒駕遭逮 宅神：若處罰夠重一次就', 'content': '\n'}, {'date': 'Thu Jan  4 14:11:54 2018', 'author': 'sevenzgod (7z)', 'title': 'Re: [新聞] 陳喬恩酒駕遭逮 宅神：若處罰夠重一次就', 'content': '\n就是國際人民的發展程度\n\n和人民選出的民意代表的程度差異性\n\n阿酒駕的都民代\n\n怎麼肯修法\n\n\n日本 皇民的故鄉\n\n酒駕的懲罰程度就真的身敗名裂啊\n\n藝人 或者是歌手等等 直接封殺 如果是吸毒持有毒品甚至是在節目上出現的畫面都會打馬賽克\n\n老百姓直接開除\n\n吊銷執照 如果車上還有其他乘客採連坐法\n\n而且不只是罰高額罰金\n\n還會有刑責 是要被關的\n\n在日本酒駕是0容忍 真的是身敗名裂\n\n\n在台灣\n\n立委 或者是政府官員\n\n調離現職 等風聲過 又回到原本的位置\n\n不然就是含淚開記者會向大家道歉\n\n又沒事了\n\n就是立委民代本身就是酒駕者\n\n誰
KING (亂世狂刀)', 'title': 'Re: [新聞]北韓今日又撥打熱線！南韓24小時內接到3通', 'content': '\n'}, {'date': 'Thu Jan  4 14:16:14 2018', 'author': 'applehpsh ()', 'title': 'Re: [新聞] 砍大稻埕煙火響應環保？ 柯：是議員刪的', 'content': '\n'}, {'date': 'Sat Nov 11 23:55:13 2017', 'author': 'Kay731 (K少)', 'title': '[公告] 八卦板板規(2017.11.11)', 'content': '\n\n╭─────────────────────────────────────╮\n│ 本板為PTT八卦板，文章、推文及板務處理原則均依循中華民國法律、站規規範發\u3000│\n│ 文者，不得因不知相關板規而免卻責任。                                     │\n╰─────────────────────────────────────╯\n\n'}, {'date': 'Sun Dec 31 19:47:40 2017', 'author': 'Unawakened (微瘦敏鎬)', 'title': '[協尋] 新北市78歲婦人(代po)', 'content': '\n阿嬤離家後失蹤了\n天氣很冷 希望阿嬤能快點回家\n\n-\n'}, {'date': 'Wed Dec 27 08:59:55 2017', 'author': 'Kay731 (K少)', 'title': 'Fw: [協尋] 12/24下午新北耶誕城廣場遺失鑽石項鍊', 'content': '\n'}, {'date': None, 'author': None, 'title': None, 'content': None}, {'date': 'Thu Jan  4 14:00:58 2018', 'author': 'zzzz8931 (宅男)', 'title': '[新聞] 林務局「森林跳棋」像情趣用品？原創者回', 'content': '\n林務局「森林跳棋」像情趣用品？原創者回應了\n\n'}, {'date': 'Thu Jan  4 14:01:39 2018', 'author': 'science556 (啾啾人)', 'title': '[問卦] 全形是不是新注音輸入法中的肥宅?', 'content': '\n\n如題\n\n每次不小心切到全形\n\n怒氣值都會爆衝\n\n明明使用頻率遠輸英文大小寫，中文半形\n\n卻硬要跑出來佔一格超大的空間\n\n有沒有很眼熟?\n\n根本就跟八卦版的肥宅一樣無用又佔空間啊\n\n不小心碰到肥宅還會覺的很噁心!!!!\n\n\n\n-----\nSent from JPTT on my Asus ASUS_Z012DA.\n\n--\n'}, {'date': 'Thu Jan  4 14:01:59 2018', 'author': 'serialhon (人生如夢)', 'title': '[新聞] 砍大稻埕煙火響應環保？ 柯：是議員刪的', 'content': '\n砍大稻埕煙火響應環保？ 柯：是議員刪的\n\n2018-01-04 12:32\n\n台北市長柯文哲說大稻埕煙火節有編預算，但被議員刪掉。圖為柯文哲今參加4座共融式遊戲場啟用記者會，好奇地看小朋友操作遊戲設施。（記者王藝菘攝）\n\n〔記者沈佩瑤／台北報導〕全台深陷霾害影響、空氣品質低落，部分縣市宣布一年一度的跨年活動不放煙火，響應環保。但台北市不只跨年照慣例放煙火，每年8月登場的大稻埕煙火節，同樣編列預算打算繼續辦。然而觀傳局長簡余晏3日備詢時表示，由於議會教育委員會已取消河岸音樂祭的400萬預算，「今年完全沒有煙火。」\n\n上午台北市長柯文哲出席活動後，被問到對於取消大稻埕煙火，是否為響應環保時直言「沒有啦，我們是有編預算，但被議員刪掉」，還說要去查查看是哪議員刪的。\n\n至於是否支持繼續大稻程煙火，柯重申他認為空污是每一天的事情，例如節慶鞭炮也是減量，但不會 ...

# %%
resp = app.test_client().get('/ptt_crawler')
print(resp.data)
print(json.loads(resp.data.decode()))
聞] 陳喬恩酒駕後首度發文道歉'}, {'date': 'Thu Jan  4 14:13:20 2018', 'author': 'alcloth (呂布)', 'content': '\n剛剛在水管看到YOUTUBE看到狗蛋大兵的剪輯\n\n才突然發覺郝劭文其實以前拍了不少港片跟國片\n\n小時候大家幾乎都認識郝劭文\n\n賺的錢應該也蠻多的\n\n一直到那些年電影之前他就突然消失了\n\n之前傳出還在日本料理店打工\n\n感覺現在過的不是很好\n\n郝劭文是不是小時了了大未必佳的典型啊?\n\n\n--\n', 'title': '[問卦] 郝劭文是不是小時了了大未必佳的典型?'}, {'date': 'Thu Jan  4 14:13:40 2018', 'author': 'cheinshin (那就這樣吧)', 'content': '\nLTN\n\n\n正副駕駛空中大吵 駕駛艙竟沒人開飛機！\n\n2018-01-04 13:48\n\n〔即時新聞／綜合報導〕印度捷特航空（Jet Airways）日前一架編號9W119從倫敦飛往孟\n買的班機，在飛行9小時後，正副駕駛因故吵架，', 'title': '[新聞] 正副駕駛空中大吵 駕駛艙竟沒人開飛機！'}, {'date': 'Thu Jan  4 14:16:06 2018', 'author': 'KINMENKING (亂世狂刀)', 'content': '\n', 'title': 'Re: [新聞]北韓今日又撥打熱線！南韓24小時內接到3通'}, {'date': 'Thu Jan  4 14:16:14 2018', 'author': 'applehpsh ()', 'content': '\n', 'title': 'Re: [新聞] 砍大稻埕煙火響應環保？ 柯：是議員刪的'}, {'date': 'Sat Nov 11 23:55:13 2017', 'author': 'Kay731 (K少)', 'content': '\n\n╭─────────────────────────────────────╮\n│ 本板為PTT八卦板，文章、推文及板務處理原則均依循中華民國法律、站規規範發\u3000│\n│ 文者，不得因不知相關板規而免卻責任。                                     │\n╰─────────────────────────────────────╯\n\n', 'title': '[公告] 八卦板板規(2017.11.11)'}, {'date': 'Sun Dec 31 19:47:40 2017', 'author': 'Unawakened (微瘦敏鎬)', 'content': '\n阿嬤離家後失蹤了\n天氣很冷 希望阿嬤能快點回家\n\n-\n', 'title': '[協尋] 新北市78歲婦人(代po)'}, {'date': 'Wed Dec 27 08:59:55 2017', 'author': 'Kay731 (K少)', 'content': '\n', 'title': 'Fw: [協尋] 12/24下午新北耶誕城廣場遺失鑽石項鍊'}, {'date': None, 'author': None, 'content': None, 'title': None}, {'date': 'Thu Jan  4 14:00:58 2018', 'author': 'zzzz8931 (宅男)', 'content': '\n林務局「森林跳棋」像情趣用品？原創者回應了\n\n', 'title': '[新聞] 林務局「森林跳棋」像情趣用品？原創者回'}, {'date': 'Thu Jan  4 14:01:39 2018', 'author': 'science556 (啾啾人)', 'content': '\n\n如題\n\n每次不小心切到全形\n\n怒氣值都會爆衝\n\n明明使用頻率遠輸英文大小寫，中文半形\n\n卻硬要跑出來佔一格超大的空間\n\n有沒有很眼熟?\n\n根本就跟八卦版的肥宅一樣無用又佔空間啊\n\n不小心碰到肥宅還會覺的很噁心!!!!\n\n\n\n-----\nSent from JPTT on my Asus ASUS_Z012DA.\n\n--\n', 'title': '[問卦] 全形是不是新注音輸入法中的肥宅?'}, {'date': 'Thu Jan  4 14:01:59 2018', 'author': 'serialhon (人生如夢)', 'content': '\n砍大稻埕煙火響應環保？ 柯：是議員刪的\n\n2018-01-04 12:32\n\n台北市長柯文哲說大稻埕煙火節有編預算，但被議員刪掉。圖為柯文哲今參加4座共融式遊戲場啟用記者會，好奇地看小朋友操作遊戲設施。（記者王藝菘攝）\n\n〔記者沈佩瑤／台北報導〕全台深陷霾害影響、空氣品質低落，部分縣市宣布一年一度的跨年活動不放煙火，響應環保。但台北市不只跨年照慣例放煙火，每年8月登場的大稻埕煙火節，同樣編列預算打算繼續辦。然而觀傳局長簡余晏3日備詢時表示，由於議會教育委員會已取消河岸音樂祭的400萬預算，「今年完全沒有煙火。」\n\n上午台北市長柯文哲出席活動後，被問到對於取消大稻埕煙火，是否為響應環保時直言「沒有啦，我們是有編預算，但被議員刪掉」，還說要去查查看是哪議員刪的。\n\n至於是否支持繼續大稻程煙火，柯重申他認為空污是每一天的事情，例如節慶鞭炮也是減量，但不會一下就把它消滅掉，所以他對大稻埕煙火的態度是已經放很多年了，也許可以加一些 ...

# %%
resp = app.test_client().post(
    '/ptt_crawler',
    data=json.dumps({'board':'Baseball','page':3}),
    content_type='application/json'
)

print(json.loads(resp.data.decode()))
# Out:
# [{'date': 'Thu Jan  4 11:44:23 2018', 'author': 'teramars (tomorrow never knows)', 'content': '\n\n 基特想再賣球星\u3000勇士有意接手\n\n\n馬林魚自從基特(Derek Jeter)團隊接手後，不斷賣掉陣中球星，目前包括先發捕手瑞爾\n\n穆托（J. T. Realmuto）、年輕好手耶里奇（Christian Yelich）也是基特下一波要交易\n\n的目標，目前傳出勇士有興趣與馬林魚交易。\n\n\n馬林魚經營權易主後，共同老闆基特上任首要就是整頓球隊，並極力壓低團隊薪資，陸續\n\n送走球星史丹頓（Giancarlo Stanton）、戈登（Dee Gordon）、歐祖納（Marcell Ozuna\n\n）等人，送走鈴木一朗也讓許多球迷心碎。\n\n\n在交易許多人後，陣中也傳出有球員不滿，包括透過媒體放話交易的先發捕手瑞爾穆托，\n\n以及要求高層出來面對的年輕好手耶里奇，兩人不但都希望求去，也都成為基特下一波交\n\n易的目標。\n\n\n據外媒報導，目前勇士已經與馬林魚有接觸，勇士不是第一次表達對耶里奇的興趣，而如\n\n今加入瑞爾穆托更讓勇士更積極推動此交易，畢竟勇士農場深度在全大聯盟排名數一數二\n\n，擁有多達7名百大新秀，符合馬林魚的建隊方針。\n\n\n瑞爾穆托在馬林魚4年，去年繳出.278打擊率、17支全壘打、65分打點，耶里奇在馬林魚5\n\n年，去年.282打擊率、18支全壘打、81分打點，兩人都是馬林魚的攻擊重心。\n\n\n\n                                                      記者張克銘／綜合報導\n', 'title': '[新聞] 基特想再賣球星\u3000勇士有意接手'}, {'date': 'Thu Jan  4 11:53:40 2018', 'author': 's295566 (s295566)', 'content': '\n收到白宮邀請\u3000太空人預定春訓造訪\n\n作者：曹玉烱 ‧ 2018年01月04日 10:33\n太空人總裁Reid Ryan今天（4日）表示，球隊已收到來自白宮的邀請，而他們預計會在春\n訓期間前往白宮會見總統Donald Trump。\n\n太空人之所以選擇春訓期間前往白宮，主要是因為2018年賽程他們並